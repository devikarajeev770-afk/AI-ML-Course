# %% [markdown]
# <a href="https://colab.research.google.com/github/devikarajeev770-afk/AI-ML-Course/blob/main/Module_1_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Basic matrix operations

# %% [markdown]
# ## Print outputs in python
#
# Use the `print()` command to display content of a variable in python. For example a message 'Hello Python' can be displayed as:

# %%
print("Hello Python")
# Out:
# Hello Python

# %% [markdown]
# Displaying output of a variable and operation in python as follows:

# %%
a=2
b=5
print("Value of a:",a)
print("Value of b: ", b)
print("Value of the operation, a+(2b) is:",a+(2*b))
# Out:
# Value of a: 2
# Value of b:  5
# Value of the operation, a+(2b) is: 12

# %% [markdown]
# ## Reading a value to a variable in python
# Use the funtion `input()`. For example :

# %%
v=input("Enter the value:")
print(" The value read is:", v)
# Out:
# Enter the value:676576
#  The value read is: 676576

# %% [markdown]
# ## Reading a vector in `python`

# %%
import numpy as np
v1=np.array([1,2,3])
v2=np.array([2,4,5])
a=2.3
print("The vector is: {}".format(v1))
print('The scalar product of {}  with {} is : {}'.format(v1,a,a*v1))
print('The linear combination of {} and {} is :{}'.format(v1,v2,a*v1+v2))
# Out:
# The vector is: [1 2 3]
# The scalar product of [1 2 3]  with 2.3 is : [2.3 4.6 6.9]
# The linear combination of [1 2 3] and [2 4 5] is :[ 4.3  8.6 11.9]

# %% [markdown]
# ## Matrix operations in `python`

# %%
M1=np.array([[1,2,3],[2,3,4],[4,5,6]])
M2=np.array([[3,2,1],[2,4,6],[5,6,7]])
print('Sum of matrices:',M1+M2)
print('Scalar product:',a*M1)
print('Element-wise product:',M1*M2)
print('Matrix Product',np.dot(M1,M2))
# Out:
# Sum of matrices: [[ 4  4  4]
#  [ 4  7 10]
#  [ 9 11 13]]
# Scalar product: [[ 2.3  4.6  6.9]
#  [ 4.6  6.9  9.2]
#  [ 9.2 11.5 13.8]]
# Element-wise product: [[ 3  4  3]
#  [ 4 12 24]
#  [20 30 42]]
# Matrix Product [[22 28 34]
#  [32 40 48]
#  [52 64 76]]
